# %%
! pip install wheel
! pip install pandas
! pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
taxi1 = pd.read_csv('/content/train.csv')
taxi1
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %%
taxi1.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %%
taxi1_subset=taxi1[['id', 'pickup_datetime',
        'pickup_longitude', 'pickup_latitude',
       'dropoff_longitude', 'dropoff_latitude',
       'trip_duration']]
taxi1_subset
# Out:
#                 id      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0        id2875421  2016-03-14 17:24:55        -73.982155        40.767937
# 1        id2377394  2016-06-12 00:43:35        -73.980415        40.738564
# 2        id3858529  2016-01-19 11:35:24        -73.979027        40.763939
# 3        id3504673  2016-04-06 19:32:31        -74.010040        40.719971
# 4        id2181028  2016-03-26 13:30:55        -73.973053        40.793209
# ...            ...                  ...               ...              ...
# 1458639  id2376096  2016-04-08 13:31:04        -73.982201        40.745522
# 1458640  id1049543  2016-01-10 07:35:15        -74.000946        40.747379
# 1458641  id2304944  2016-04-22 06:57:41        -73.959129        40.768799
# 1458642  id2714485  2016-01-05 15:56:26        -73.982079        40.749062
# 1458643  id1209952  2016-04-05 14:44:25        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude  trip_duration
# ...

# %%
taxi1_subset.isna().sum()
# Out:
# id                   0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# trip_duration        0
# dtype: int64

# %%
taxi1_subset.describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count      1.458644e+06     1.458644e+06       1.458644e+06      1.458644e+06
# mean      -7.397349e+01     4.075092e+01      -7.397342e+01      4.075180e+01
# std        7.090186e-02     3.288119e-02       7.064327e-02      3.589056e-02
# min       -1.219333e+02     3.435970e+01      -1.219333e+02      3.218114e+01
# 25%       -7.399187e+01     4.073735e+01      -7.399133e+01      4.073588e+01
# 50%       -7.398174e+01     4.075410e+01      -7.397975e+01      4.075452e+01
# 75%       -7.396733e+01     4.076836e+01      -7.396301e+01      4.076981e+01
# max       -6.133553e+01     5.188108e+01      -6.133553e+01      4.392103e+01
#
#        trip_duration
# count   1.458644e+06
# mean    9.594923e+02
# std     5.237432e+03
# min     1.000000e+00
# 25%     3.970000e+02
# 50%     6.620000e+02
# 75%     1.075000e+03
# max     3.526282e+06

# %%
taxi1_subset.dtypes
# Out:
# id                    object
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# trip_duration          int64
# dtype: object

# %%
taxi1_subset=taxi1_subset.dropna()

# %%
taxi1_subset.isna().sum()
# Out:
# id                   0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# trip_duration        0
# dtype: int64

# %%
taxi1_subset.hist(bins=60,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'pickup_longitude'}>,
#         <Axes: title={'center': 'pickup_latitude'}>],
#        [<Axes: title={'center': 'dropoff_longitude'}>,
#         <Axes: title={'center': 'dropoff_latitude'}>],
#        [<Axes: title={'center': 'trip_duration'}>, <Axes: >]],
#       dtype=object)

# %%
# Assuming you have a DataFrame called "taxi1_subset" with a "pickup_datetime" column
taxi1_subset['pickup_datetime'] = pd.to_datetime(taxi1_subset['pickup_datetime'])

# Plot the histogram
taxi1_subset['pickup_datetime'].hist(bins=60
                                     , figsize=(20, 10))
# Out:
# <Axes: >

# %%
#from this we can infer that the month of april in 2016
#had a lot of traffic therefore longer pickup to drop hours

# %%
pickup_longitude = taxi1_subset['pickup_longitude']
pickup_latitude = taxi1_subset['pickup_latitude']
dropoff_longitude = taxi1_subset['dropoff_longitude']
dropoff_latitude = taxi1_subset['dropoff_latitude']


# Calculate the Manhattan distance
distance = abs(dropoff_longitude - pickup_longitude) + abs(dropoff_latitude - pickup_latitude)

#new feature!
taxi1_subset['distance'] = distance
taxi1_subset
# Out:
#                 id     pickup_datetime  pickup_longitude  pickup_latitude  \
# 0        id2875421 2016-03-14 17:24:55        -73.982155        40.767937
# 1        id2377394 2016-06-12 00:43:35        -73.980415        40.738564
# 2        id3858529 2016-01-19 11:35:24        -73.979027        40.763939
# 3        id3504673 2016-04-06 19:32:31        -74.010040        40.719971
# 4        id2181028 2016-03-26 13:30:55        -73.973053        40.793209
# ...            ...                 ...               ...              ...
# 1458639  id2376096 2016-04-08 13:31:04        -73.982201        40.745522
# 1458640  id1049543 2016-01-10 07:35:15        -74.000946        40.747379
# 1458641  id2304944 2016-04-22 06:57:41        -73.959129        40.768799
# 1458642  id2714485 2016-01-05 15:56:26        -73.982079        40.749062
# 1458643  id1209952 2016-04-05 14:44:25        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude  trip_duration  distance
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame called "taxi_data" with a "pickup_datetime" column
taxi1_subset['pickup_datetime'] = pd.to_datetime(taxi1_subset['pickup_datetime'])

# Define peak periods (e.g., morning rush hour)
morning_rush_hour_start = 16
morning_rush_hour_end = 20

# Create binary indicator for morning rush hour
taxi1_subset['morning_rush_hour'] = (
    (taxi1_subset['pickup_datetime'].dt.hour >= morning_rush_hour_start) &
    (taxi1_subset['pickup_datetime'].dt.hour <= morning_rush_hour_end)
).astype(int)

taxi1_subset
# Out:
#                 id     pickup_datetime  pickup_longitude  pickup_latitude  \
# 0        id2875421 2016-03-14 17:24:55        -73.982155        40.767937
# 1        id2377394 2016-06-12 00:43:35        -73.980415        40.738564
# 2        id3858529 2016-01-19 11:35:24        -73.979027        40.763939
# 3        id3504673 2016-04-06 19:32:31        -74.010040        40.719971
# 4        id2181028 2016-03-26 13:30:55        -73.973053        40.793209
# ...            ...                 ...               ...              ...
# 1458639  id2376096 2016-04-08 13:31:04        -73.982201        40.745522
# 1458640  id1049543 2016-01-10 07:35:15        -74.000946        40.747379
# 1458641  id2304944 2016-04-22 06:57:41        -73.959129        40.768799
# 1458642  id2714485 2016-01-05 15:56:26        -73.982079        40.749062
# 1458643  id1209952 2016-04-05 14:44:25        -73.979538        40.781750
#
#          dropoff_longitude  dropoff_latitude  trip_duration  distance  \
# ...

# %%
taxi1_subset = taxi1_subset.drop('morning_rush_hour', axis=1)

# %%
import pandas as pd


testdata = pd.read_csv("/content/test.csv")

testdata.isna().sum()

#no null values in the testing dataset
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# dtype: int64

# %%
testdata.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'passenger_count',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'store_and_fwd_flag'],
#       dtype='object')

# %%
testsubset= testdata[['id','pickup_datetime',
       'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
       'dropoff_latitude']]
testsubset
# Out:
#                id      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       id3004672  2016-06-30 23:59:58        -73.988129        40.732029
# 1       id3505355  2016-06-30 23:59:53        -73.964203        40.679993
# 2       id1217141  2016-06-30 23:59:47        -73.997437        40.737583
# 3       id2150126  2016-06-30 23:59:41        -73.956070        40.771900
# 4       id1598245  2016-06-30 23:59:33        -73.970215        40.761475
# ...           ...                  ...               ...              ...
# 625129  id3008929  2016-01-01 00:02:52        -74.003464        40.725105
# 625130  id3700764  2016-01-01 00:01:52        -74.006363        40.743782
# 625131  id2568735  2016-01-01 00:01:24        -73.972267        40.759865
# 625132  id1384355  2016-01-01 00:00:28        -73.976501        40.733562
# 625133  id0621643  2016-01-01 00:00:22        -73.981850        40.716881
#
#         dropoff_longitude  dropoff_latitude
# ...

# %%
pickup_longitude = testsubset['pickup_longitude']
pickup_latitude = testsubset['pickup_latitude']
dropoff_longitude = testsubset['dropoff_longitude']
dropoff_latitude = testsubset['dropoff_latitude']


# Calculate the Manhattan distance
distance = abs(dropoff_longitude - pickup_longitude) + abs(dropoff_latitude - pickup_latitude)

#new feature!
testsubset['distance'] = distance
testsubset
# Out:
# <ipython-input-20-d37f98d9c35a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testsubset['distance'] = distance
#                id      pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       id3004672  2016-06-30 23:59:58        -73.988129        40.732029
# 1       id3505355  2016-06-30 23:59:53        -73.964203        40.679993
# 2       id1217141  2016-06-30 23:59:47        -73.997437        40.737583
# 3       id2150126  2016-06-30 23:59:41        -73.956070        40.771900
# 4       id1598245  2016-06-30 23:59:33        -73.970215        40.761475
# ...           ...                  ...               ...              ...
# 625129  id3008929  2016-01-01 00:02:52        -74.003464        40.725105
# ...

# %%
features = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'distance']
target = 'trip_duration'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming you have a DataFrame called "taxi1" with the desired columns
features = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'distance']
target = 'trip_duration'

# Split the data into training and validation sets
train_data, val_data = train_test_split(taxi1_subset, test_size=0.2, random_state=42)

# %%
# Create a Random Forest Regressor model
model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)
